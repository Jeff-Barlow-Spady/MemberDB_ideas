# %%
import pandas as pd
import numpy as np
import seaborn as sns
import dataprep as dp

# %%
data = pd.read_csv(r"C:\Users\toast\Downloads\Urban_Primary_Land_Vegetation_Inventory.csv")

# %%
data.describe(include='all')
# Out:
#         END_DT      START_DT  \
# count      0.0  1.282500e+04
# unique     NaN           NaN
# top        NaN           NaN
# freq       NaN           NaN
# mean       NaN  2.015053e+13
# std        NaN  0.000000e+00
# min        NaN  2.015053e+13
# 25%        NaN  2.015053e+13
# 50%        NaN  2.015053e+13
# 75%        NaN  2.015053e+13
# max        NaN  2.015053e+13
#
#                                                  the_geom            ID  \
# count                                               12825  12825.000000
# unique                                              12825           NaN
# top     MULTIPOLYGON (((-113.66250098308744 53.5460576...           NaN
# freq                                                    1           NaN
# mean                                                  NaN   6413.000000
# std                                                   NaN   3702.402936
# min                                                   NaN      1.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12825 entries, 0 to 12824
# Data columns (total 62 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   END_DT      0 non-null      float64
#  1   START_DT    12825 non-null  int64
#  2   the_geom    12825 non-null  object
#  3   ID          12825 non-null  int64
#  4   NSR         12825 non-null  object
#  5   PRIMECLAS1  12825 non-null  object
#  6   PRIMECLAS2  5629 non-null   object
#  7   PRIMECLAS3  1283 non-null   object
#  8   STYPE1      12825 non-null  object
#  9   STYPE2      5630 non-null   object
#  10  STYPE3      1286 non-null   object
#  11  STYPEPER1   12825 non-null  int64
#  12  STYPEPER2   12825 non-null  int64
#  13  STYPEPER3   12825 non-null  int64
#  14  LANDCLAS1   12825 non-null  object
#  15  LANDCLAS2   5629 non-null   object
#  16  LANDCLAS3   1283 non-null   object
#  17  MOISTURE1   6667 non-null   object
#  18  MOISTURE2   3650 non-null   object
# ...

# %%
# !pip install pdfplumber
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 47.5/47.5 kB 2.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.6/5.6 MB 11.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.7/2.7 MB 12.4 MB/s eta 0:00:00
# ...
#   WARNING: The script pypdfium2.exe is installed in 'C:\Users\toast\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pdfplumber.exe is installed in 'C:\Users\toast\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pdfplumber as pp

# %%
df = pd.read_csv(r"C:\Users\toast\Downloads\Shrubscriber, Neighbourhood-Edmonton Neighbourhood Data.csv")
df.head(20)
df
# Out:
#                           Community  ... Members
# 0                      Abbottsfield  ...     NaN
# 1                            Albany  ...     NaN
# 2                    Alberta Avenue  ...     NaN
# 3           Alberta Park Industrial  ...     NaN
# 4                        Aldergrove  ...     NaN
# 5                            Allard  ...     NaN
# 6                         Allendale  ...     NaN
# 7                         Ambleside  ...     NaN
# 8                    Anthony Henday  ...     NaN
# 9           Anthony Henday Big Lake  ...     NaN
# 10       Anthony Henday Castledowns  ...     NaN
# 11         Anthony Henday Clareview  ...     NaN
# 12       Anthony Henday Energy Park  ...     NaN
# 13        Anthony Henday Horse Hill  ...     NaN
# 14     Anthony Henday Lake District  ...     NaN
# 15          Anthony Henday Mistatim  ...     NaN
# 16           Anthony Henday Rampart  ...     NaN
# 17             Anthony Henday South  ...     NaN
# ...

# %%
df.isnull().sum()
# Out:
# Community                         0
# Municipality                      0
# Priority                        369
# Teachers                        370
# Partners                        339
# Social Score                    403
# Area (sq km)                      1
# Trees/sq km                       8
# Temperature                       8
# Household Income                403
# Low Income (After Tax)          138
# Renters                         383
# Unemployment                    403
# Under 18                        403
# Over 65                         403
# Education Levels                403
# Non Citizens                    403
# Non-Male                        403
# English As a Second Language    403
# Single Parent Household         138
# Tennent Households              138
# Single Person Household         403
# Members                         396
# dtype: int64

# %%
columns_to_drop = ['Municipality', 'Priority', 'Teachers', 'Partners', 'Under 18', 
                   'Over 65', 'Education Levels', 'Non Citizens', 'Non-Male', 
                   'English As a Second Language', 'Single Parent Household', 
                   'Tennent Households', 'Single Person Household', 'Members', 'Unemployment', 'Renters', 'Social Score', 'Household Income']

df_clean = df.drop(columns_to_drop, axis=1)

# %%
df_clean
# Out:
#                     Community  Area (sq km)  ...  Temperature  Low Income (After Tax)
# 0                Abbottsfield           0.4  ...         26.7                   28.3%
# 1                      Albany           0.8  ...         23.7                    6.7%
# 2              Alberta Avenue           1.7  ...         24.2                   16.5%
# 3     Alberta Park Industrial           0.7  ...         25.7                     NaN
# 4                  Aldergrove           1.5  ...         25.9                   11.3%
# ..                        ...           ...  ...          ...                     ...
# 398  Yellowhead Corridor East           1.4  ...         26.3                     NaN
# 399  Yellowhead Corridor West           1.2  ...         26.4                     NaN
# 400                      York           1.2  ...         27.0                    9.6%
# 401     Youngstown Industrial           0.5  ...         27.1                     NaN
# ...

# %%
df_clean.describe()
# Out:
#        Area (sq km)  Trees/sq km  Temperature
# count    402.000000   395.000000   395.000000
# mean       1.953234   746.756962    24.544304
# std        3.853120   628.764905     1.873780
# min        0.200000     0.000000    18.700000
# 25%        0.800000   153.650000    23.600000
# 50%        1.200000   676.500000    25.100000
# 75%        1.700000  1148.350000    25.900000
# max       53.400000  3508.800000    27.900000

# %%
df_clean.dropna(inplace=False)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Community               403 non-null    object
#  1   Area (sq km)            402 non-null    float64
#  2   Trees/sq km             395 non-null    float64
#  3   Temperature             395 non-null    float64
#  4   Low Income (After Tax)  265 non-null    object
# dtypes: float64(3), object(2)
# memory usage: 15.9+ KB

# %%
import seaborn as sns

# %%
sns.boxplot(x='Area (sq km)', y='Trees/sq km', data=df_clean, palette='Set2')
# Out:
# <AxesSubplot: xlabel='Area (sq km)', ylabel='Trees/sq km'>

# %%
df_clean.to_csv(r"C:\Users\toast\Downloads\Datasets\edm_clean.csv", index=False)

# %%
df_clean.to_excel(r"C:\Users\toast\Downloads\Datasets\edm_clean.xlsx", index=False)
